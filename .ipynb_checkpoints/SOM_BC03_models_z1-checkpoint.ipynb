# %%
import scipy.optimize as so
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, Column, join
import SOMPY as sompy
from mpl_toolkits.axes_grid1 import make_axes_locatable
import astropy.io.fits as pyfits
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.coordinates import Angle
from matplotlib import gridspec
import scipy.optimize as so
from matplotlib import ticker


def rms(a):
    return np.sqrt(np.mean(np.square(a)))
def abmag2fluxjk(mag):
    return (10**((mag-23.9)/(-2.5))/(10.0**6.0)) ##jansky

def mag2sollum(mag,redshift):
    fl=abmag2fluxjk(mag)*10**(-26.0) ##Watts/m2/hz
    v_wave=2520.
    v_freq=(299792458.0)/(v_wave*10.0**(-9.0))
    d=cosmo.luminosity_distance(redshift).value
    d=d*3.086e+22 ## MPC to meter
    lum=(1.0+redshift)**2.0*(fl)*v_freq*4.0*np.pi*(d**2.0) ## in watts
    return lum/(3.828*10**26)


cosmo = FlatLambdaCDM(H0=70 * u.km / u.s / u.Mpc, Om0=0.3)

# %matplotlib inline
# Out:
# /anaconda2/lib/python2.7/site-packages/SOMPY/__init__.py:5: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
# ...

# %%
redshift=1.0
catal=np.genfromtxt('sedlist/All_mags_z1.0.cat',dtype=[('names', 'S50'), ('u', 'f8'), ('b', 'f8'), ('v', 'f8'), ('r', 'f8'),('i', 'f8'), ('z', 'f8'), ('y', 'f8'), ('j', 'f8'), ('h', 'f8'), ('k', 'f8'),('ch1', 'f8'), ('ch2', 'f8'), ('ch3', 'f8'), ('ch4', 'f8')])
    

ub=(catal['u']-catal['b'])
bv=(catal['b']-catal['v'])
vr=(catal['v']-catal['r'])
ri=(catal['r']-catal['i'])
iz=(catal['i']-catal['z'])
zy=(catal['z']-catal['y'])
yj=(catal['y']-catal['j'])
jh=(catal['j']-catal['h'])
hk=(catal['h']-catal['k'])
kc1=(catal['k']-catal['ch1'])
c1c2=(catal['ch1']-catal['ch2'])
c2c3=(catal['ch2']-catal['ch3'])
c3c4=(catal['ch3']-catal['ch4'])

ageo=[]
for bbb in range(len(catal['names'])):
    ageo.append(float(catal['names'][bbb][9:15]))
ageo=np.array(ageo)
selage=(ageo<=cosmo.age(redshift).value) 


def bordare_rang(redshift):
    catal=np.genfromtxt('sedlist/All_mags_z1.0.cat',dtype=[('names', 'S50'), ('u', 'f8'), ('b', 'f8'), ('v', 'f8'), ('r', 'f8'),('i', 'f8'), ('z', 'f8'), ('y', 'f8'), ('j', 'f8'), ('h', 'f8'), ('k', 'f8'),('ch1', 'f8'), ('ch2', 'f8'), ('ch3', 'f8'), ('ch4', 'f8')])
    mass=np.genfromtxt('Mass_table_fromcsp.cat')
    met,age,tau,ebv,ml=np.zeros_like(catal['b']),np.zeros_like(catal['b']),np.zeros_like(catal['b']),np.zeros_like(catal['b']),np.zeros_like(catal['b']),
    uvj=np.zeros_like(catal['names'])
    for i in range(len(catal['names'])):
        met[i]=int(catal['names'][i][28:30])
        age[i]=float(catal['names'][i][9:15])
        tau[i]=float(catal['names'][i][19:24])
        ebv[i]=float(catal['names'][i][34:38])
        inja=(np.abs(mass[:,0]-tau[i])<=0.01)&(np.abs(mass[:,2]-(np.log10(10.0**9.0*np.float(age[i])))<=0.01))
        ml[i]=(np.median(mass[inja,7])) 
        if ~(((catal['r'][i]-catal['j'][i])>0.8*(catal['j'][i]-catal['k'][i])+0.7)&((catal['r'][i]-catal['j'][i])>1.3)&((catal['j'][i]-catal['k'][i])<1.5))&((catal['r'][i]-catal['j'][i])<1.5):
            uvj[i]='sb'
        elif ~(((catal['r'][i]-catal['j'][i])>0.8*(catal['j'][i]-catal['k'][i])+0.7)&((catal['r'][i]-catal['j'][i])>1.3)&((catal['j'][i]-catal['k'][i])<1.5))&((catal['r'][i]-catal['j'][i])>=1.5):
            uvj[i]='sd'
        else:
            uvj[i]='qg'

    ub=(catal['u']-catal['b'])
    bv=(catal['b']-catal['v'])
    vr=(catal['v']-catal['r'])
    ri=(catal['r']-catal['i'])
    iz=(catal['i']-catal['z'])
    zy=(catal['z']-catal['y'])
    yj=(catal['y']-catal['j'])
    jh=(catal['j']-catal['h'])
    hk=(catal['h']-catal['k'])
    kc1=(catal['k']-catal['ch1'])
    c1c2=(catal['ch1']-catal['ch2'])
#    c2c3=(catal['ch2']-catal['ch3'])
#    c3c4=(catal['ch3']-catal['ch4'])
#&(ebv<=0.7)&(~((age>1.0)&(tau<1.5)))
    selage=(age<=cosmo.age(redshift).value)&(~np.isnan(ub))&(~np.isnan(bv))&(~np.isnan(vr))&(~np.isnan(ri))&(~np.isnan(iz))&(~np.isnan(zy))&(~np.isnan(yj))&(~np.isnan(jh))&(~np.isnan(hk))&(~np.isnan(kc1))&(~np.isnan(c1c2))
    dat=np.array([ub[selage],bv[selage],vr[selage],ri[selage],iz[selage],zy[selage],yj[selage],jh[selage],hk[selage],kc1[selage],c1c2[selage]])
    data=dat.T
    par=[met[selage],age[selage],tau[selage],ebv[selage],catal['ch2'][selage],uvj[selage]]
    return data,par

data,par=bordare_rang(redshift)
print (np.shape(data))
# Out:
# (13776, 11)

# %%
msz0 = 80
msz1 = 60
sm = sompy.SOMFactory.build(data, mapsize=[msz0,msz1], mapshape='planar', lattice='rect', initialization='pca') 
sm.train(n_job=4, shared_memory = 'no')
# Out:
#  Training...
#  pca_linear_initialization took: 0.098000 seconds
#  Rough training...
#  radius_ini: 10.000000 , radius_final: 2.500000, trainlen: 11
#
#  epoch: 1 ---> elapsed time:  4.358000, quantization error: 0.566656
#
#  epoch: 2 ---> elapsed time:  1.684000, quantization error: 0.349187
#
#  epoch: 3 ---> elapsed time:  0.679000, quantization error: 0.261534
#
#  epoch: 4 ---> elapsed time:  0.553000, quantization error: 0.248670
#
#  epoch: 5 ---> elapsed time:  0.699000, quantization error: 0.233962
#
#  epoch: 6 ---> elapsed time:  0.599000, quantization error: 0.215724
#
#  epoch: 7 ---> elapsed time:  0.716000, quantization error: 0.196221
#
#  epoch: 8 ---> elapsed time:  0.570000, quantization error: 0.175656
#
#  epoch: 9 ---> elapsed time:  0.654000, quantization error: 0.154962
#
#  epoch: 10 ---> elapsed time:  0.576000, quantization error: 0.134837
#
#  epoch: 11 ---> elapsed time:  0.684000, quantization error: 0.116643
#
#  Finetune training...
# ...

# %%
nom=2000
dat2=np.array([ub[selage],bv[selage],vr[selage],ri[selage],iz[selage],zy[selage],yj[selage],jh[selage],hk[selage],kc1[selage],c1c2[selage]])
data2=dat2.T
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
print ac
# Out:
# [[   0   59   59]
#  [   0   53   53]
#  [   0   43   43]
#  ...
#  [  68   32 4112]
#  [  74   35 4475]
#  [  79   40 4780]]

# %%
somcol=np.zeros(11,object)
plt.figure(figsize=(12,10))
colors=[r'$\rm u-B$',r'$\rm B-V$',r'$\rm V-r$',r'$ \rm r-i^{+}$',r'$ \rm I-Z$',r'$ \rm Z-Y$',r'$ \rm Y-J$',r'$ \rm J-H$',r'$ \rm H-K$',r'$ \rm K-CH1$',r'$ \rm CH1-CH2$']
codebook = sm._normalizer.denormalize_by(sm.data_raw,sm.codebook.matrix)
    
for ind in range(0,4):
    mp = codebook[:, ind].reshape(sm.codebook.mapsize[0],sm.codebook.mapsize[1])
    plt.subplot(3,4,ind+1)
    ax = plt.gca()
    im=ax.imshow(mp,origin='lower')
    somcol[ind]=np.ndarray.flatten(mp)
    ax.axis('off')
    plt.text(2,msz0-10,str(colors[ind]),size=20)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
for ind in range(4,8):
    mp = codebook[:, ind].reshape(sm.codebook.mapsize[0],sm.codebook.mapsize[1])
    plt.subplot(3,4,ind+1)
    ax = plt.gca()
    im=ax.imshow(mp,origin='lower')
    somcol[ind]=np.ndarray.flatten(mp)
    ax.axis('off')
    plt.text(2,msz0-10,str(colors[ind]),size=20)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)
for ind in range(8,11):
    mp = codebook[:, ind].reshape(sm.codebook.mapsize[0],sm.codebook.mapsize[1])
    plt.subplot(3,4,ind+1)
    ax = plt.gca()
    im=ax.imshow(mp,origin='lower')
    somcol[ind]=np.ndarray.flatten(mp)
    ax.axis('off')
    plt.text(2,msz0-10,str(colors[ind]),size=20)
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(im, cax=cax)

plt.tight_layout()
#plt.savefig('plots/INPUT_colors_z'+str(redshift)+'_cosmos.png')

# %%
ndtype=[('id', "S15"), ('ra', float), ('dec', float),('ubc',float), ('bvc',float),('vrc',float), ('ric',float), 
        ('izc',float), ('zyc',float), ('yjc',float), ('jhc',float), ('hkc',float),('k1c',float), ('c12c',float),
        ('c23c',float),('c34c',float),('eub',float), ('ebv',float),('evr',float), ('eri',float), 
        ('eiz',float), ('ezy',float), ('eyj',float), ('ejh',float), ('ehk',float),('ekc',float), ('ec12',float),
        ('ec23',float),('ec34',float),('zc',float), ('massc',float), ('sfrc',float), ('agec',float), 
        ('ebvc',float), ('kmag',float),('ekmag',float), ('MU',float),('MV',float), ('MJ',float), ('overdensity',float),('env', "S15")]

cosmos=np.genfromtxt('cosmos_z1_color+env.cat',dtype=ndtype)

mub,mbv,mvr,mri,miz,mzy,myj,mjh,mhk,mk1,mc12=1.0,1.2,1.4,1.6,1.1,1.4,2.0,1.5,1.6,1.2,0.85
cub,cbv,cvr,cri,ciz,czy,cyj,cjh,chk,ck1,cc12=0.2,-0.4,0.1,-0.3,0.1,0.1,-0.2,0.2,-0.2,0.1,0.04

ra=np.array(cosmos['ra'])
dec=np.array(cosmos['dec'])

ubc=mub*np.array(cosmos['ubc'])+cub
bvc=mbv*np.array(cosmos['bvc'])+cbv
vrc=mvr*np.array(cosmos['vrc'])+cvr
ric=mri*np.array(cosmos['ric'])+cri
izc=miz*np.array(cosmos['izc'])+ciz
zyc=mzy*np.array(cosmos['zyc'])+czy
yjc=myj*np.array(cosmos['yjc'])+cyj
jhc=mjh*np.array(cosmos['jhc'])+cjh
hkc=mhk*np.array(cosmos['hkc'])+chk
k1c=mk1*np.array(cosmos['k1c'])+ck1
c12c=mc12*np.array(cosmos['c12c'])+cc12
eub=np.array(cosmos['eub'])
ebv=np.array(cosmos['ebv'])
evr=np.array(cosmos['evr'])
eri=np.array(cosmos['eri'])
eiz=np.array(cosmos['eiz'])
ezy=np.array(cosmos['ezy'])
eyj=np.array(cosmos['eyj'])
ejh=np.array(cosmos['ejh'])
ehk=np.array(cosmos['ehk'])
ekc=np.array(cosmos['ekc'])
ec12=np.array(cosmos['ec12'])


zc=np.array(cosmos['zc'])
massc=np.array(cosmos['massc'])
sfrc=np.array(cosmos['sfrc'])
agec=np.array(cosmos['agec'])
ebvc=np.array(cosmos['ebvc'])
kmag=np.array(cosmos['kmag'])
ekmag=np.array(cosmos['ekmag'])

dens=np.array(cosmos['overdensity'])
env=np.array(cosmos['env'])

# %%
a=plt.hist(ub[selage],normed='True',histtype='step',bins=30,label='BC03')
a=plt.hist(somcol[0],normed='True',histtype='step',bins=30,label='SOM')
a=plt.hist(ubc,normed='True',histtype='step',bins=50,label='COSMOS')
plt.legend()
plt.xlim([-1,3])
plt.xlabel('COLOR')
plt.ylabel('normalized count')
# Out:
# /anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0,0.5,'normalized count')

# %%
plt.figure(figsize=(8,5))

plt.plot(ub[selage],bv[selage],'r.',alpha=0.2,label='BC03 Models')
#plt.plot(k1c,c12c,'bo',label='Phot-z',alpha=0.1)
bbb=plt.plot(somcol[0],somcol[1],'k-',alpha=0.8,label='SOM CELLS')
plt.xlim([-0.2,1.2])
plt.ylim([-0.5,1.3])
plt.legend(loc=4,numpoints=1)
plt.tight_layout()

# %%
plt.figure(figsize=(5,6))
ax = plt.gca()

dat2=np.array([ubc,bvc,vrc,ric,izc,zyc,yjc,jhc,hkc,k1c,c12c])
data2=dat2.T
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    k+=1

im=ax.scatter(ypz,xpz,c=massc,marker='x',cmap='plasma')
plt.text(3,4,'COSMOS Galaxies at z~'+str(redshift),size=14)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log(M_{*}/M_{\odot})$', labelpad=-50,size=20)
ax.set_xlim([0,msz1-1])
ax.set_ylim([0,msz0-1])
print len(data2)

plt.savefig('plots/stellar_z'+str(redshift)+'_cosmos.png')
# Out:
# 13718

# %%
cos=np.genfromtxt('SOM_props_z1cosmos.cat')
plt.figure(figsize=(12,7))
ax=plt.subplot(1,2,1)
im=ax.scatter(cos[:,3],cos[:,4],c=cos[:,5])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log(M_{*}/M_{\odot})$', labelpad=-47,size=20)
ax.set_xlim([0,msz1-1])
ax.set_ylim([0,msz0-1])

ax1=plt.subplot(1,2,2)
im1=ax1.scatter(cos[:,3],cos[:,4],c=cos[:,6])
divider = make_axes_locatable(ax1)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb2=plt.colorbar(im1, cax=cax)
cb.set_label(r'$\rm Log(M_{*}/M_{\odot})$', labelpad=-47,size=20)
ax1.set_xlim([0,msz1-1])
ax1.set_ylim([0,msz0-1])
# Out:
# (0, 79)

# %%
plt.figure(figsize=(6,7))
ax = plt.gca()

dat2=np.array([ubc,bvc,vrc,ric,izc,zyc,yjc,jhc,hkc,k1c,c12c])
data2=dat2.T
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
oo=np.zeros(len(ac))
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    if len(str(env[k]))==5:##field
        oo[k]=1
    if len(env[k])==8:##filament
        oo[k]=2
    if len(env[k])==7: ##cluster
        oo[k]=3
    k+=1


im=ax.scatter(ypz,xpz,c=oo)
plt.text(3,4,'COSMOS Galaxies at z~'+str(redshift),size=14)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Structure$', labelpad=-47,size=20)
ax.set_xlim([0,msz1-1])
ax.set_ylim([0,msz0-1])
print len(data2)
# Out:
# 13718

# %%
plt.figure(figsize=(6,7))
ax = plt.gca()

dat2=np.array([ubc,bvc,vrc,ric,izc,zyc,yjc,jhc,hkc,k1c,c12c])
data2=dat2.T
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    k+=1

dens[dens>5]=5
im=ax.scatter(ypz,xpz,c=dens)
plt.text(3,4,'COSMOS Galaxies at z~'+str(redshift),size=14)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Overdensity$', labelpad=-47,size=20)
ax.set_xlim([0,msz1-1])
ax.set_ylim([0,msz0-1])
print len(data2)
# Out:
# 13718

# %%
plt.figure(figsize=(10,8))
mp = codebook[:, 2].reshape(sm.codebook.mapsize[0],sm.codebook.mapsize[1])    
ax = plt.gca()
im=ax.imshow(mp,origin='lower')
ac=sm.bmu_ind_to_xy(sm.project_data(data))
xboz,yboz=np.zeros(len(ac)),np.zeros(len(ac))
k=0
for i in ac:
    xboz[k]=i[0]
    yboz[k]=i[1]
    k+=1

ax.plot(yboz,xboz,'ko')
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])
# Out:
# (0, 80)

# %%
from scipy.integrate import quad
def integrand(t, tau):
     return np.exp(-t/tau)

def ssfr(age,tau):
    I = quad(integrand, 0, age, args=(tau))[0]
    return np.log10(np.exp(-age/tau)/I)-9.0

mass=np.genfromtxt('Mass_table_fromcsp.cat')
data,par=bordare_rang(redshift)
a=sm.bmu_ind_to_xy(sm.project_data(data))

x,y,age,tau,ebv,mv,mk,met,ssf=np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a))
k=0
for i in a:
    x[k]=i[0]
    y[k]=i[1]
    met[k]=(par[0][k])
    age[k]=(par[1][k])
    tau[k]=(par[2][k])
    ebv[k]=(par[3][k])
    ssf[k]=ssfr(age[k],tau[k])
    for juj in range(len(mass[:,2])):
        if (np.abs(mass[juj,2]-np.log10(10.0**9.0*np.float(par[1][k])))<=0.01)&(np.abs(mass[juj,0]-par[2][k])<0.001):
            mk[k]=(mass[juj,7])
            #mv[k]=(mass[juj,6])
            
    k+=1
    
testr=np.zeros([msz0,msz1])
for i in range(msz0):
    for j in range(msz1):
        unja=(x==i)&(y==j)
        testr[i,j]=np.median(ebv[unja])
# Out:
# /anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,4,1)
ax = plt.gca()
im=ax.scatter(y,x,c=age,cmap='jet',s=40)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Age (Gyr)$', labelpad=-40,size=20)
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])


plt.subplot(1,4,2)
ax = plt.gca()
im=ax.scatter(y,x,c=tau,cmap='jet',s=40)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm \tau (Gyr)$', labelpad=-38,size=20)
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])


plt.subplot(1,4,3)
ax = plt.gca()
im=ax.scatter(y,x,c=ebv,cmap='jet',s=40)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm E(B-V)$', labelpad=-38,size=20)
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])

plt.subplot(1,4,4)
ax = plt.gca()
im=ax.scatter(y,x,c=mk,cmap='jet',s=40)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm M/L_{K}$', labelpad=-45,size=20)
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])


plt.tight_layout()
plt.savefig('plots/SOM_properties_z'+str(redshift)+'.png')

# %%
from scipy import interpolate
yi = np.linspace(np.min(x), np.max(x),msz0*10)
xi = np.linspace(np.min(y), np.max(y),msz1*10)
XI, YI = np.meshgrid(xi, yi)
points = np.vstack((y,x)).T
points = np.asarray(points)
plt.figure(figsize=(16,5))

values = np.asarray(age)
DEMage = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,4,1)
ax = plt.gca()
im=ax.imshow(DEMage,origin='lower',cmap='plasma')
ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Age (Gyr)$', labelpad=-30,size=10)

values = np.asarray(ssf)
DEMtau = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,4,2)
ax = plt.gca()
im=ax.imshow(DEMtau,vmin=-15,origin='lower',cmap='plasma')
ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log\ sSFR (yr^{-1})$', labelpad=-42,size=10)

values = np.asarray(ebv)
DEMebv = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,4,3)
ax = plt.gca()
im=ax.imshow(DEMebv,origin='lower',cmap='plasma')
ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm E(B-V)$', labelpad=-35,size=10)

values = np.asarray(mk)
DEMmlr = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,4,4)
ax = plt.gca()
im=ax.imshow(DEMmlr,origin='lower',cmap='plasma')

ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm M/L_{V}$', labelpad=-35,size=10)
plt.savefig('plots/interpolated_props_z'+str(redshift)+'.png')

# %%
plt.figure(figsize=(8,5))

values = np.asarray(ssf)
DEMtau = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,2,1)
ax = plt.gca()
im=ax.imshow(DEMtau,vmin=-15,origin='lower',cmap='viridis')
ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log\ sSFR (yr^{-1})$', labelpad=-50,size=10)

values = np.asarray(ebv)
DEMebv = interpolate.griddata(points, values, (XI,YI), method='linear')
plt.subplot(1,2,2)
ax = plt.gca()
im=ax.imshow(DEMebv,origin='lower',cmap='viridis')
ax.axis('off')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm E(B-V)$', labelpad=-33,size=10)
plt.tight_layout()
#plt.savefig('/Users/shemmati/GoogleDrive/JS/plotwork/models.eps')

# %%
galmlr=[]
for bozche in range(len(xpz)):
    m2l=DEMmlr[np.int(xpz[bozche]*10),np.int(ypz[bozche]*10)]
    lum=mag2sollum(kmag[bozche],zc[bozche])
    galmlr.append(m2l*lum)


m1=massc
m2=np.log10(galmlr)

mass1=m1[np.isfinite(m2)&np.isfinite(m1)&(m2<13)]
mass2=m2[np.isfinite(m2)&np.isfinite(m1)&(m2<13)]
mcanhst2=np.array(mass1-mass2)
sel=(np.abs(mcanhst2) > 0.5)
olf=float(np.sum(sel))/len(sel)
sel=(np.abs(mcanhst2) <=0.5)
print 'stats'+'\t'+str(round(olf,3))+'\t'+str(round(rms(mcanhst2),3))+'\t'+str(round(1.48*np.median(np.abs(mcanhst2)),3))+'\t'+str(round(rms(mcanhst2[sel]),3))

plt.figure(figsize=(8,5))
plt.plot(mass1,mass2,'g.',alpha=0.2,label='0.9<specz<1.1]')
plt.legend(numpoints=1,loc=4)
plt.plot([5,12],[5,12],'r--')
plt.xlim([8,12])
plt.ylim([8,12])
plt.xlabel(r'$\rm Log (M_{*}/M_{\odot})- SEDfit$',size=20)
plt.ylabel(r'$\rm Log(M_{*}/M_{\odot})-SOM$',size=20)
# Out:
# stats	0.082	0.298	0.21	0.199
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# Text(0,0.5,'$\\rm Log(M_{*}/M_{\\odot})-SOM$')

# %%
fig = plt.figure(num=None, figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')

gs = gridspec.GridSpec(2, 1,height_ratios=[4,1],hspace=0.03) 

print 'cosmos'+'\t'+str(round(olf,3))+'\t'+str(round(rms(mcanhst2),3))+'\t'+str(round(1.48*np.median(np.abs(mcanhst2)),3))+'\t'+str(round(rms(mcanhst2[sel]),3))

ax0 = plt.subplot(gs[0])
hb=ax0.hexbin(mass1,mass2, gridsize=100, bins='log', cmap='inferno')
cb = fig.colorbar(hb, ax=ax0)
cb.set_label('log10(N)')
ax0.set_ylabel(r'$\rm Log\ (M_{*}/M_{\odot}) \ SOM$',fontsize=20)
ax0.plot([4,12],[4,12],'k--',linewidth=1)
ax0.set_xlim([8,max(mass2)])
ax0.set_ylim([8,max(mass2)])
ax0.text(8.1,11.4,r'$\rm OLF = 0.08$',size=15,color='w')
ax0.text(8.1,11.1,r'$\rm \sigma _{F}=0.29$',size=15,color='W')
ax0.text(8.1,10.8,r'$\rm \sigma _{NMAD}=0.20$',size=15,color='W')
ax0.text(8.1,10.5,r'$\rm \sigma_O=0.19$',size=15,color='W')
ax0.text(10.5,8.2,r'$\rm 0.8<z<1.2$',size=15,color='W')

ax0.axes.get_xaxis().set_ticks([])
plt.tick_params(axis='both', which='major', labelsize=13)

ax2 = plt.subplot(gs[1])
ax2.set_xlabel(r'$\rm Log\ (M_{*}/M_{\odot})\ COSMOS\ SEDfit$',fontsize=20, labelpad=10)
ax2.set_ylabel(r'$\rm \Delta \ Log(M)$',fontsize=20,labelpad=10)
ax2.set_ylim([-0.5,0.5])
hb=ax2.hexbin(mass1,mcanhst2, gridsize=100, bins='log', cmap='inferno')
cb = fig.colorbar(hb, ax=ax2)
cb.set_label('log10(N)')
ax2.plot([6,12],[0,0],'k--')
ax2.set_xlim([8,max(mass2)])
ax2.set_ylim([-1.,1.])
ax2.yaxis.set_ticks([-1.0,-0.5,0.,0.5,1.0])
plt.tick_params(axis='both', which='major', labelsize=13)
#plt.savefig('plots/Mass_SOMvsSED.png')
# Out:
# cosmos	0.082	0.298	0.21	0.199

# %%
m1=massc
m2=cos[:,5]

mass1=m1[np.isfinite(m2)&np.isfinite(m1)&(m2<13)]
mass2=m2[np.isfinite(m2)&np.isfinite(m1)&(m2<13)]
mcanhst2=np.array(mass1-mass2)
sel=(np.abs(mcanhst2) > 0.5)
olf=float(np.sum(sel))/len(sel)
sel=(np.abs(mcanhst2) <=0.5)
print 'stats'+'\t'+str(round(olf,3))+'\t'+str(round(rms(mcanhst2),3))+'\t'+str(round(1.48*np.median(np.abs(mcanhst2)),3))+'\t'+str(round(rms(mcanhst2[sel]),3))


fig = plt.figure(num=None, figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')
gs = gridspec.GridSpec(2, 1,height_ratios=[4,1],hspace=0.03) 

ax0 = plt.subplot(gs[0])
hb=ax0.hexbin(mass1,mass2, gridsize=100, bins='log', cmap='plasma')
cb = fig.colorbar(hb, ax=ax0)
cb.set_label('log10(N)')
ax0.set_ylabel(r'$\rm Log\ (M_{*}/M_{\odot}) \ SOM$',fontsize=20)
ax0.plot([4,12],[4,12],'k--',linewidth=1)
ax0.set_xlim([8,max(mass2)])
ax0.set_ylim([8,max(mass2)])
ax0.text(8.1,11.4,r'$\rm OLF = 0.03$',size=15,color='w')
ax0.text(8.1,11.1,r'$\rm \sigma _{F}=0.22$',size=15,color='W')
ax0.text(8.1,10.8,r'$\rm \sigma _{NMAD}=0.18$',size=15,color='W')
ax0.text(8.1,10.5,r'$\rm \sigma_O=0.19$',size=15,color='W')
ax0.text(10.5,8.2,r'$\rm 0.8<z<1.2$',size=15,color='W')

ax0.axes.get_xaxis().set_ticks([])
plt.tick_params(axis='both', which='major', labelsize=13)

ax2 = plt.subplot(gs[1])
ax2.set_xlabel(r'$\rm Log\ (M_{*}/M_{\odot})\ COSMOS\ SEDfit$',fontsize=20, labelpad=10)
ax2.set_ylabel(r'$\rm \Delta \ Log(M)$',fontsize=20,labelpad=10)
ax2.set_ylim([-0.5,0.5])
hb=ax2.hexbin(mass1,mcanhst2, gridsize=100, bins='log', cmap='plasma')
cb = fig.colorbar(hb, ax=ax2)
cb.set_label('log10(N)')
ax2.plot([6,12],[0,0],'k--')
ax2.set_xlim([8,max(mass2)])
ax2.set_ylim([-1.,1.])
ax2.yaxis.set_ticks([-1.0,-0.5,0.,0.5,1.0])
plt.tick_params(axis='both', which='major', labelsize=13)
plt.savefig('plots/Mass_SOMvsSED.png')
# Out:
# stats	0.033	0.226	0.185	0.191

# %%
def err_gen2(iii,num):
    color=np.array([ubc[iii],bvc[iii],vrc[iii],ric[iii],izc[iii],zyc[iii],yjc[iii],jhc[iii],hkc[iii],k1c[iii],c12c[iii]])
    colerr=np.array([eub[iii],ebv[iii],evr[iii],eri[iii],eiz[iii],ezy[iii],eyj[iii],ejh[iii],ehk[iii],ekc[iii],ec12[iii]])
    newcol,kkmag=np.zeros([num,len(color)]),np.zeros(num)
    redshift=zc[iii]
    for j in range(num):
        for i in range(len(color)):
            newcol[j,i]=np.random.normal(color[i],colerr[i],1)
            kkmag[j]=np.random.normal(kmag[iii],ekmag[iii],1)
    
    dat2=np.array([newcol[:,0],newcol[:,1],newcol[:,2],newcol[:,3],newcol[:,4],newcol[:,5],newcol[:,6],newcol[:,7],
             newcol[:,8],newcol[:,9],newcol[:,10]])
    da=dat2.T
    import time
    start = time.time()
    ac=sm.bmu_ind_to_xy(sm.project_data(da))
    end = time.time()
    time_took = (end - start)
    return time_took

x_t = 10**np.linspace(1,10,10)
y_t=[]
for boz in x_t:
    y_t.append(err_gen2(9,np.int(boz)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-b6b1c71d1b24> in <module>()
#      22 y_t=[]
#      23 for boz in x_t:
# ---> 24     y_t.append(err_gen2(9,np.int(boz)))
#
# <ipython-input-32-b6b1c71d1b24> in err_gen2(iii, num)
#       7         for i in range(len(color)):
#       8             newcol[j,i]=np.random.normal(color[i],colerr[i],1)
# ----> 9             kkmag[j]=np.random.normal(kmag[iii],ekmag[iii],1)
#      10
#      11     dat2=np.array([newcol[:,0],newcol[:,1],newcol[:,2],newcol[:,3],newcol[:,4],newcol[:,5],newcol[:,6],newcol[:,7],
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(6,4))

plt.style.use('default')
plt.style.use('seaborn')
plt.plot(x_t,y_t,'o-',color='#094465',label='CPU Core-i7')

plt.legend(loc=2)
plt.xscale('log')
plt.yscale('log')

plt.xlabel('Total number of galaxies')
plt.ylabel('Time to map to the SOM (s)')
# Out:
# [1.e+01 1.e+02 1.e+03 1.e+04 1.e+05 1.e+06 1.e+07 1.e+08 1.e+09 1.e+10]

# %%
from matplotlib.colors import LogNorm
from matplotlib.gridspec import GridSpec
#plt.style.use('dark_background')
plt.style.use('default')

def err_gen(iii,num):
    color=np.array([ubc[iii],bvc[iii],vrc[iii],ric[iii],izc[iii],zyc[iii],yjc[iii],jhc[iii],hkc[iii],k1c[iii],c12c[iii]])
    colerr=np.array([eub[iii],ebv[iii],evr[iii],eri[iii],eiz[iii],ezy[iii],eyj[iii],ejh[iii],ehk[iii],ekc[iii],ec12[iii]])
    newcol,kkmag=np.zeros([num,len(color)]),np.zeros(num)
    redshift=zc[iii]
    for j in range(num):
        for i in range(len(color)):
            newcol[j,i]=np.random.normal(color[i],colerr[i],1)
            kkmag[j]=np.random.normal(kmag[iii],ekmag[iii],1)
    
    dat2=np.array([newcol[:,0],newcol[:,1],newcol[:,2],newcol[:,3],newcol[:,4],newcol[:,5],newcol[:,6],newcol[:,7],
             newcol[:,8],newcol[:,9],newcol[:,10]])
    da=dat2.T
    import time
    start = time.time()
    ac=sm.bmu_ind_to_xy(sm.project_data(da))
    end = time.time()
    time_took = (end - start)

    x,y=np.zeros(len(ac)),np.zeros(len(ac))
    k=0
    for i in ac:
        x[k]=i[0]
        y[k]=i[1]
        k+=1
    
    gmlr,gage,gssfr,gebv=[],[],[],[]
    for bozche in range(len(x)):
        m2l=DEMmlr[np.int(x[bozche]*10),np.int(y[bozche]*10)]
        lum=mag2sollum(kkmag[bozche],redshift)
        gmlr.append(np.log10(m2l*lum))
        gage.append(DEMage[np.int(x[bozche]*10),np.int(y[bozche]*10)])
        gssfr.append(DEMtau[np.int(x[bozche]*10),np.int(y[bozche]*10)])
        gebv.append(DEMebv[np.int(x[bozche]*10),np.int(y[bozche]*10)])
    
    fig=plt.figure(figsize=(12,7))
    gs=GridSpec(4,4) # 2 rows, 3 columns

    ax=fig.add_subplot(gs[0:4,0:2]) # First row, first column
    import scipy.stats as st
    xmin, xmax = 0, msz1
    ymin, ymax = 0,msz0
    xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
    positions = np.vstack([xx.ravel(), yy.ravel()])
    values = np.vstack([y, x])
    kernel = st.gaussian_kde(values)
    f = np.reshape(kernel(positions).T, xx.shape)
    cfset = ax.contourf(xx, yy, f,cmap='plasma',label='probab')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="8%", pad=0.05)
    cb=plt.colorbar(cfset, cax=cax)
    cb.set_label(r'$\rm Kernel\ Density\ Function$', labelpad=-53,size=15)

    #ax.axis('off')

    daha=color.T
    daha = daha.reshape(1, -1) 
    bc=sm.bmu_ind_to_xy(sm.project_data(daha))
    #ax.plot(bc[0][1],bc[0][0],'k.')
    ax.set_xlim([0,msz1-1])
    ax.set_ylim([0,msz0-1])
    
    ax1=fig.add_subplot(gs[0:2,2])
    ax1.hist(gmlr,bins=20,normed=True,color='y')
    ax1.set_xlabel(r'$\rm Log(M_{*}/M_{\odot})$',fontsize=12)
    #ax1.plot([np.median(gmlr),np.median(gmlr)],[0,10],'r--')
    ax1.text(9.5,9,r'$\rm Median=$'+np.str(np.round(np.median(gmlr),2)),size=12)
    ax1.text(9.5,8,r'$\rm STD=$'+np.str(np.round(np.std(gmlr),2)),size=12)
    ax1.set_xlim([8,12])
    ax1.set_ylim([0,10])

    ax2=fig.add_subplot(gs[2:4,2])
    ax2.hist(gssfr,bins=20,normed=True,color='y')
    ax2.set_xlabel(r'$\rm Log(sSFR) yr^{-1}$',fontsize=12)
    ax2.text(-13,9,r'$\rm Median=$'+np.str(np.round(np.median(gssfr),2)),size=12)
    ax2.text(-13,8,r'$\rm STD=$'+np.str(np.round(np.std(gssfr),2)),size=12)
    ax2.set_xlim([-15,-8])
    ax2.set_ylim([0,10])

    
    ax3=fig.add_subplot(gs[0:2,3])
    ax3.hist(gage,bins=20,normed=True,color='y')
    ax3.set_xlabel(r'$\rm Age (Gyr)$',fontsize=12)
    #ax3.plot([np.median(gage),np.median(gage)],[0,10],'r--')
    ax3.text(1.5,9,r'$\rm Median=$'+np.str(np.round(np.median(gage),2)),size=12)
    ax3.text(1.5,8,r'$\rm STD=$'+np.str(np.round(np.std(gage),2)),size=12)
    ax3.set_xlim([0,5])
    ax3.set_ylim([0,10])


    ax4=fig.add_subplot(gs[2:4,3])
    ax4.hist(gebv,bins=20,normed=True,color='y')
    ax4.set_xlabel(r'$\rm E(B-V)$',fontsize=12)
    ax4.set_xlim([0,1])
    ax4.set_ylim([0,10])
    ax4.text(0.4,9,r'$\rm Median=$'+np.str(np.round(np.median(gebv),2)),size=12)
    ax4.text(0.4,8,r'$\rm STD=$'+np.str(np.round(np.std(gebv),2)),size=12)
 
    #ax4.plot([np.median(gebv),np.median(gebv)],[0,10],'r--')
    
    plt.tight_layout()
    plt.savefig('plots/galaxy_id'+str(iii)+'_onSOM.png')
    
    p=[bc[0][1],bc[0][0],np.median(gmlr),np.std(gmlr),np.median(gssfr),np.std(gssfr),np.median(gage),np.std(gage),np.median(gebv),np.std(gebv),time_took]
    return p

b=err_gen(9,10000)

#f=open('SOM_props_z1cosmos2.cat','w+')
#for i in range(6390,len(ra)):
#    b=err_gen(i,10000)
#    f.write(str(i)+'\t'+str(ra[i])+'\t'+str(dec[i])+'\t'+str(b[0])+'\t'+str(b[1])+'\t'+str(b[2])+'\t'+str(b[3])+'\t'
#            +str(b[4])+'\t'+str(b[5])+'\t'+str(b[6])+'\t'+str(b[7])+'\t'+str(b[8])+'\t'+str(b[9])+'\n')
#f.close()

# %%
x_t=[10,100,1000,10000,100000,1000000]
y_t=[0.0073,0.011,0.06,0.580,6.129,62.467]
y2_t = [0.007,0.01,0.05,0.2,1.0,10.0]
y3_t = [0.007,0.01,0.05,0.18,0.98,7.0]

print b[-1]
# Out:
# 62.4679369926

# %%
plt.figure(figsize=(6,4))

plt.style.use('default')
plt.style.use('seaborn')
plt.plot(x_t,y_t,'o-',color='#094465',label='CPU Core-i7')
plt.plot(x_t,y2_t,'o-',color='#009999',label='GPU Guadro P5000')
plt.plot(x_t,y3_t,'o-',color='#336699',label='GPU TITAN V')

plt.legend(loc=2)
plt.xscale('log')
plt.yscale('log')

plt.xlabel('Total number of galaxies')
plt.ylabel('Time to map to the SOM (s)')
plt.tight_layout()
plt.savefig('speed.png')

# %%
plt.figure(figsize=(6,8))
ax = plt.gca()
im=ax.scatter(y,x,c=ssf,cmap='jet_r',s=40)
#ax.plot(ypz,xpz,'kx',alpha=0.4)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="10%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log sSFR (yr^{-1})$', labelpad=-50,size=20)
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])

# %%
from matplotlib.gridspec import GridSpec

fig=plt.figure(figsize=(10,10))

gs=GridSpec(5,2) # 2 rows, 3 columns

ax1=fig.add_subplot(gs[0:3,0]) # First row, first column
ssfrc=np.log10(10.0**sfrc/10.0**massc)
ssfrc[ssfrc<-15.5]=-15.5
im=ax1.scatter(ypz,xpz,c=ssfrc,cmap='jet_r',s=40)
divider = make_axes_locatable(ax1)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log sSFR (yr^{-1}) \ COSMOS$', labelpad=-37,size=10)
ax1.set_xlim([0,msz1-1])
ax1.set_ylim([0,msz0-1])

ax2=fig.add_subplot(gs[0:3,1]) # First row, second column
ssfsom=[]
for bozche in range(len(xpz)):
    ssfsom.append(DEMtau[xpz[bozche]*10,ypz[bozche]*10])
ssfsom=np.array(ssfsom)
    
im=ax2.scatter(ypz,xpz,c=ssfsom,cmap='jet_r',s=40)
divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log sSFR (yr^{-1}) \ SOM$', labelpad=-47,size=10)
ax2.set_xlim([0,msz1-1])
ax2.set_ylim([0,msz0-1])



ax3=fig.add_subplot(gs[3:5,:]) # First row, third column
sf=[]
for kh in range(len(sfrc)):
    sf.append(np.log10(10.0**sfrc[kh]/10.0**massc[kh]))

    
import scipy.stats as st
xmin, xmax = 8, 12
ymin, ymax = -16, -7

# Peform the kernel density estimate
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([massc, sf])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
# Contourf plot
cfset = ax3.contourf(xx, yy, f, cmap='Reds',label='COSMOS')
## Or kernel density estimate plot instead of the contourf plot
#ax.imshow(np.rot90(f), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
# Contour plot
cset = ax3.contour(xx, yy, f, colors='r')
# Label plot
ax3.clabel(cset, inline=1, fontsize=10)
#ax3.plot(massc,sf,'r.',alpha=0.4,label='cosmos')
#ax3.plot(m2,ssfsom,'b.',alpha=0.3,label='SOM')
bozx=m2[np.isfinite(ssfsom)&np.isfinite(m2)]
bozy=ssfsom[np.isfinite(ssfsom)&np.isfinite(m2)]
values = np.vstack([bozx,bozy])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
# Contourf plot
cfset = ax3.contourf(xx, yy, f, cmap='Blues')
# Contour plot
cset = ax3.contour(xx, yy, f, colors='b')
# Label plot
ax3.clabel(cset, inline=1, fontsize=10)
#ax3.plot(massc,sf,'r.',alpha=0.4,label='cosmos')

ax3.set_xlim([8.7,11.5])
ax3.set_ylim([-14.,-7])
ax3.legend(loc=3,numpoints=1)
ax3.set_xlabel(r'$\rm Log(M_{*}/M_{\odot})$',size=18)
ax3.set_ylabel(r'$\rm Log\ sSFR (yr^{-1})$',size=18)
plt.savefig('plots/sSFR_SOMvsSED.png')

# %%
from matplotlib.gridspec import GridSpec

fig=plt.figure(figsize=(10,10))

gs=GridSpec(5,2) # 2 rows, 3 columns

ax1=fig.add_subplot(gs[0:3,0]) # First row, first column
ssfrc=np.log10(10.0**sfrc/10.0**massc)
ssfrc[ssfrc<-15.5]=-15.5
im=ax1.scatter(ypz,xpz,c=ssfrc,cmap='jet_r',s=40)
divider = make_axes_locatable(ax1)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log sSFR (yr^{-1}) \ COSMOS$', labelpad=-37,size=10)
ax1.set_xlim([0,msz1-1])
ax1.set_ylim([0,msz0-1])

ax2=fig.add_subplot(gs[0:3,1]) # First row, second column
ssfsom=[]
for bozche in range(len(xpz)):
    ssfsom.append(DEMtau[xpz[bozche]*10,ypz[bozche]*10])
ssfsom=cos[:,7]#np.array(ssfsom)
    
im=ax2.scatter(ypz,xpz,c=ssfsom,cmap='jet_r',s=40)
divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm Log sSFR (yr^{-1}) \ SOM$', labelpad=-47,size=10)
ax2.set_xlim([0,msz1-1])
ax2.set_ylim([0,msz0-1])



ax3=fig.add_subplot(gs[3:5,:]) # First row, third column
sf=[]
for kh in range(len(sfrc)):
    sf.append(np.log10(10.0**sfrc[kh]/10.0**massc[kh]))

    
import scipy.stats as st
xmin, xmax = 8, 12
ymin, ymax = -16, -7

# Peform the kernel density estimate
xx, yy = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([xx.ravel(), yy.ravel()])
values = np.vstack([massc, sf])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
# Contourf plot
cfset = ax3.contourf(xx, yy, f, cmap='Reds',label='COSMOS')
## Or kernel density estimate plot instead of the contourf plot
#ax.imshow(np.rot90(f), cmap='Blues', extent=[xmin, xmax, ymin, ymax])
# Contour plot
cset = ax3.contour(xx, yy, f, colors='r')
# Label plot
ax3.clabel(cset, inline=1, fontsize=10)
#ax3.plot(massc,sf,'r.',alpha=0.4,label='cosmos')
#ax3.plot(m2,ssfsom,'b.',alpha=0.3,label='SOM')
bozx=m2[np.isfinite(ssfsom)&np.isfinite(m2)]
bozy=ssfsom[np.isfinite(ssfsom)&np.isfinite(m2)]
values = np.vstack([bozx,bozy])
kernel = st.gaussian_kde(values)
f = np.reshape(kernel(positions).T, xx.shape)
# Contourf plot
cfset = ax3.contourf(xx, yy, f, cmap='Blues')
# Contour plot
cset = ax3.contour(xx, yy, f, colors='b')
# Label plot
ax3.clabel(cset, inline=1, fontsize=10)
#ax3.plot(massc,sf,'r.',alpha=0.4,label='cosmos')

ax3.set_xlim([8.7,11.5])
ax3.set_ylim([-14.,-7])
ax3.legend(loc=3,numpoints=1)
ax3.set_xlabel(r'$\rm Log(M_{*}/M_{\odot})$',size=18)
ax3.set_ylabel(r'$\rm Log\ sSFR (yr^{-1})$',size=18)
plt.savefig('plots/sSFR_SOMvsSED.png')

# %%
p=pyfits.getdata('../NBJ_HA_EMITTERS_for_environment.fits',1)
boz=(p['DEC_NB']>0)
ra_ha,dec_ha=p['RA_NB'][boz],p['DEC_NB'][boz]
from astropy.coordinates import ICRS
from astropy import units as u
c = ICRS(ra_ha, dec_ha, unit=(u.degree, u.degree))
catalog = ICRS(ra, dec, unit=(u.degree, u.degree))
idx, d2d, d3d = c.match_to_catalog_sky(catalog)
print d2d

# %%
galage,galtau,galebv,galmlr=[],[],[],[]
for bozche in range(len(xpz)):
    galage.append(DEMage[xpz[bozche]*10,ypz[bozche]*10])
    galtau.append(DEMtau[xpz[bozche]*10,ypz[bozche]*10])
    galebv.append(DEMebv[xpz[bozche]*10,ypz[bozche]*10])
    galmlr.append(DEMmlr[xpz[bozche]*10,ypz[bozche]*10])


plt.figure(figsize=(6,6))
plt.subplot(2,2,1)
galage=np.array(galage)
heh=plt.hist(galage[np.isfinite(galage)],bins=20)
plt.xlabel(r'$\rm Age(Gyr)$',size=20)
plt.ylabel('#')
plt.xlim([0,12])
plt.subplot(2,2,2)
galtau=np.array(galtau)
heh=plt.hist(galtau[np.isfinite(galtau)],bins=20)
plt.xlabel(r'$\rm sSFR (yr^{-1})$',size=20)
#plt.xlim([0,6])
plt.subplot(2,2,3)
galebv=np.array(galebv)
heh=plt.hist(galebv[np.isfinite(galebv)],bins=20)
plt.xlabel(r'$\rm E(B-V)$',size=20)
plt.xlim([0,1])
plt.subplot(2,2,4)
galmlr=np.array(galmlr)
heh=plt.hist(galmlr[np.isfinite(galmlr)],bins=20)
plt.xlabel(r'$\rm M/L_{V}$',size=20)

plt.tight_layout()
#plt.savefig('plots/phys_param_hist_specz'+str(redshift)+'.png')

# %%
a=sm.bmu_ind_to_xy(sm.project_data(data))

x,y,uvj=np.zeros(len(a)),np.zeros(len(a)),np.zeros(len(a))
k=0
for i in a:
    x[k]=i[0]
    y[k]=i[1]
    if par[5][k]=='qg':
        uvj[k]=3
    elif par[5][k]=='sd':
        uvj[k]=2
    else:
        uvj[k]=1
    k+=1
    
testr=np.zeros([msz0,msz1])
for i in range(msz0):
    for j in range(msz1):
        unja=(x==i)&(y==j)
        testr[i,j]=np.median(uvj[unja])

plt.figure(figsize=(5,6))
ax = plt.gca()
im=ax.scatter(y,x,c=uvj,cmap='jet',s=40)
ax.set_xlim([0,msz1-1])
ax.set_ylim([0,msz0-1])
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="8%", pad=0.05)
cb=plt.colorbar(im, cax=cax)
cb.set_label(r'$\rm UVJ$', labelpad=-40,size=20)

# %%
plt.figure(figsize=(6,8))
ax = plt.gca()

uvc=np.array(cosmos['MU']-cosmos['MV'])
vjc=np.array(cosmos['MV']-cosmos['MJ'])

qg=(((uvc)>0.8*(vjc)+0.7)&((uvc)>1.3)&((vjc)<1.5))
sfb=~(((uvc)>0.8*(vjc)+0.7)&((uvc)>1.3)&((vjc)<1.5))
sfd=~(((uvc)>0.8*(vjc)+0.7)&((uvc)>1.3)&((vjc)<1.5))&((uvc)>1.5)


dat2=np.array([ubc[sfb],bvc[sfb],vrc[sfb],ric[sfb],izc[sfb],zyc[sfb],yjc[sfb],jhc[sfb],hkc[sfb],k1c[sfb],c12c[sfb]])
data2=dat2.T
print len(data2)
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    k+=1
ax.scatter(ypz,xpz,c='b',marker='o')

dat2=np.array([ubc[sfd],bvc[sfd],vrc[sfd],ric[sfd],izc[sfd],zyc[sfd],yjc[sfd],jhc[sfd],hkc[sfd],k1c[sfd],c12c[sfd]])
data2=dat2.T
print len(data2)
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    k+=1
ax.scatter(ypz,xpz,c='g',marker='x')
ax.set_xlim([0,msz1])
ax.set_ylim([0,msz0])

dat2=np.array([ubc[qg],bvc[qg],vrc[qg],ric[qg],izc[qg],zyc[qg],yjc[qg],jhc[qg],hkc[qg],k1c[qg],c12c[qg]])
data2=dat2.T
print len(data2)
ac=sm.bmu_ind_to_xy(sm.project_data(data2))
xpz,ypz=np.zeros(len(ac)),np.zeros(len(ac))

k=0
for i in ac:
    xpz[k]=i[0]
    ypz[k]=i[1]
    k+=1
ax.scatter(ypz,xpz,c='r',marker='s')
# Out:
# 13552
# 1201
# 166
